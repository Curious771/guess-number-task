# %% [markdown]
# # Компьютер загадывает и сам отгадывает число менее чем за 20 попыток

# %%
from game_v2 import *

# %%
score_game(game_score_v3)
# Out:
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# число 6 найдено за 7 попыток
# ...
